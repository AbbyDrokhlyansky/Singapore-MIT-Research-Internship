# %%
import pandas as pd
from glob import glob
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
stations = locations["station_id"].values
stations
# Out:
# array(['S06', 'S07', 'S08', 'S11', 'S23', 'S24', 'S25', 'S29', 'S31',
#        'S33', 'S35', 'S36', 'S39', 'S40', 'S43', 'S44', 'S46', 'S50',
#        'S55', 'S60', 'S61', 'S63', 'S64', 'S66', 'S69', 'S71', 'S72',
#        'S77', 'S78', 'S79', 'S80', 'S81', 'S82', 'S84', 'S86', 'S88',
#        'S89', 'S90', 'S91', 'S92', 'S94', 'S96', 'S100', 'S101', 'S102',
#        'S104', 'S105', 'S106', 'S107', 'S108', 'S109', 'S110', 'S111',
#        'S112', 'S113', 'S114', 'S115', 'S116', 'S117', 'S118', 'S119',
#        'S120', 'S121', 'S122', 'S123', 'S241', 'S900'], dtype=object)

# %%
len(stations)
# Out:
# 67

# %%
df=pd.DataFrame()
for station in stations:
    filenames = glob("csv/{}/DAILYDATA_*.csv".format(station))
#tryyy = pd.read_csv("csv/S06/DAILYDATA_S06_198002.csv")
#tryyy
    for filename in filenames:
    #try:
        other_df = pd.read_csv(filename, encoding='windows-1252')
        other_df = other_df.replace({'—': np.nan})
        other_df = other_df[["Station","Year","Month","Day","Daily Rainfall Total (mm)"]]
        other_df["Station"] = station
    #print(other_df)
    #do test.py filename
    
        df = df.append(other_df,ignore_index=True)
    #except UnicodeDecodeError:
        #pass
    ##other_df["timestamp_sgt"] = other_df["timestamp_sgt"].astype("datetime64[ns]")
    #other_df = other_df["Year","Month","Day","Daily Rainfall"]
#another_df = df.set_index("station_id").sort_index()
#filenames
df=df.dropna()
df
# Out:
#        Station  Year  Month  Day Daily Rainfall Total (mm)
# 0          S06  1980      1    1                         0
# 1          S06  1980      1    2                         0
# 2          S06  1980      1    3                         0
# 3          S06  1980      1    4                         0
# 4          S06  1980      1    5                      12.8
# 5          S06  1980      1    6                      25.5
# 6          S06  1980      1    7                       9.1
# 7          S06  1980      1    8                         0
# 8          S06  1980      1    9                         0
# 9          S06  1980      1   10                         0
# 10         S06  1980      1   11                         0
# 11         S06  1980      1   12                         0
# 12         S06  1980      1   13                         0
# 13         S06  1980      1   14                         0
# 14         S06  1980      1   15                         0
# ...

# %%
locations = pd.read_csv("StationLocations.csv")
locations=locations.rename(columns={"Lon (d)":"longitude","Lat (d)":"latitude"})
locations
# Out:
#    station_id  longitude  latitude
# 0         S06  103.90070   1.35240
# 1         S07  103.83340   1.34150
# 2         S08  103.82710   1.37010
# 3         S11  103.69380   1.37460
# 4         S23  103.71140   1.38580
# 5         S24  103.98260   1.36780
# 6         S25  103.86540   1.41660
# 7         S29  103.93500   1.38700
# 8         S31  103.82800   1.27450
# 9         S33  103.71000   1.30810
# 10        S35  103.75560   1.33290
# 11        S36  103.86570   1.33820
# 12        S39  103.73540   1.32620
# 13        S40  103.78962   1.40440
# 14        S43  103.88780   1.33990
# 15        S44  103.68166   1.34583
# 16        S46  103.81060   1.34160
# 17        S50  103.77680   1.33370
# 18        S55  103.88600   1.38370
# 19        S60  103.82790   1.25000
# 20        S61  103.92170   1.32300
# 21        S63  103.70420   1.32750
# 22        S64  103.76030   1.38240
# 23        S66  103.73630   1.43870
# 24        S69  103.80500   1.37000
# 25        S71  103.78150   1.29230
# ...

# %%
from sklearn.cluster import KMeans
#import plot_labelled_scatter

X = df["Daily Rainfall Total (mm)"]
X=X.values.reshape(-1,1)
X
kmeans = KMeans(n_clusters = 5)
kmeans.fit(X)
label = kmeans.predict(X)

#plot_labelled_scatter(X, kmeans.labels_, ['Cluster 1', 'Cluster 2', 'Cluster 3'])

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters = 5)
attempt = df["Daily Rainfall Total (mm)"].values.reshape(-1,1)
kmeans.fit(attempt)
label = kmeans.predict(attempt)
label
# Out:
# array([0, 0, 0, ..., 0, 3, 2], dtype=int32)

# %%
df["label"] = label
df
# Out:
#        Station  Year  Month  Day Daily Rainfall Total (mm)  label
# 0          S06  1980      1    1                         0      0
# 1          S06  1980      1    2                         0      0
# 2          S06  1980      1    3                         0      0
# 3          S06  1980      1    4                         0      0
# 4          S06  1980      1    5                      12.8      2
# 5          S06  1980      1    6                      25.5      3
# 6          S06  1980      1    7                       9.1      2
# 7          S06  1980      1    8                         0      0
# 8          S06  1980      1    9                         0      0
# 9          S06  1980      1   10                         0      0
# 10         S06  1980      1   11                         0      0
# 11         S06  1980      1   12                         0      0
# 12         S06  1980      1   13                         0      0
# ...

# %%
cluster1 = df[df["label"]==0]
cluster1
# Out:
#        Station  Year  Month  Day Daily Rainfall Total (mm)  label
# 0          S06  1980      1    1                         0      0
# 1          S06  1980      1    2                         0      0
# 2          S06  1980      1    3                         0      0
# 3          S06  1980      1    4                         0      0
# 7          S06  1980      1    8                         0      0
# 8          S06  1980      1    9                         0      0
# 9          S06  1980      1   10                         0      0
# 10         S06  1980      1   11                         0      0
# 11         S06  1980      1   12                         0      0
# 12         S06  1980      1   13                         0      0
# 13         S06  1980      1   14                         0      0
# 14         S06  1980      1   15                         0      0
# 15         S06  1980      1   16                         0      0
# ...

# %%
cluster2 = df[df["label"]==1]
cluster2
# Out:
#        Station  Year  Month  Day Daily Rainfall Total (mm)  label
# 105        S06  1980      4   15                      57.8      1
# 129        S06  1980      5    9                        74      1
# 221        S06  1980      8    9                      56.1      1
# 276        S06  1980     10    3                        70      1
# 289        S06  1980     10   16                      78.6      1
# 324        S06  1980     11   20                      47.1      1
# 410        S06  1981      2   14                      48.4      1
# 460        S06  1981      4    5                      49.9      1
# 709        S06  1981     12   10                      50.1      1
# 714        S06  1981     12   15                      52.1      1
# 715        S06  1981     12   16                      79.7      1
# 824        S06  1982      4    4                      59.4      1
# 1040       S06  1982     11    6                        67      1
# ...

# %%
cluster0 = df[df["label"]==2]
cluster0
# Out:
#        Station  Year  Month  Day Daily Rainfall Total (mm)  label
# 4          S06  1980      1    5                      12.8      2
# 6          S06  1980      1    7                       9.1      2
# 33         S06  1980      2    3                        16      2
# 52         S06  1980      2   22                      10.1      2
# 55         S06  1980      2   25                       8.1      2
# 57         S06  1980      2   27                      15.7      2
# 77         S06  1980      3   18                      11.5      2
# 78         S06  1980      3   19                      18.9      2
# 79         S06  1980      3   20                      11.3      2
# 92         S06  1980      4    2                      16.3      2
# 107        S06  1980      4   17                      11.5      2
# 110        S06  1980      4   20                       7.3      2
# 111        S06  1980      4   21                       9.2      2
# ...

# %%
cluster3 = df[df["label"]==3]
cluster3
# Out:
#        Station  Year  Month  Day Daily Rainfall Total (mm)  label
# 5          S06  1980      1    6                      25.5      3
# 25         S06  1980      1   26                      34.2      3
# 31         S06  1980      2    1                      30.7      3
# 100        S06  1980      4   10                      24.6      3
# 118        S06  1980      4   28                      27.7      3
# 124        S06  1980      5    4                      33.9      3
# 125        S06  1980      5    5                      37.2      3
# 156        S06  1980      6    5                      23.4      3
# 175        S06  1980      6   24                      39.5      3
# 197        S06  1980      7   16                      44.3      3
# 200        S06  1980      7   19                      35.5      3
# 228        S06  1980      8   16                      29.7      3
# 241        S06  1980      8   29                      38.5      3
# ...

# %%
cluster4 = df[df["label"]==4]
cluster4
# Out:
#        Station  Year  Month  Day Daily Rainfall Total (mm)  label
# 18         S06  1980      1   19                     133.5      4
# 19         S06  1980      1   20                     101.3      4
# 224        S06  1980      8   12                      87.7      4
# 972        S06  1982      8   30                     121.5      4
# 1085       S06  1982     12   21                      95.8      4
# 1341       S06  1983      9    3                     112.9      4
# 1454       S06  1983     12   25                     112.3      4
# 1480       S06  1984      1   20                      98.5      4
# 1492       S06  1984      2    1                     103.6      4
# 1522       S06  1984      3    2                     169.5      4
# 1617       S06  1984      6    5                      90.6      4
# 1992       S06  1985      6   15                      97.7      4
# 2020       S06  1985      7   13                     102.2      4
# ...

# %%
cluster0 = cluster0.set_index(["Year","Month","Day","label"], drop=True)
cluster0 = cluster0.set_index("Station")
#cluster0 = cluster0["Daily Rainfall Total (mm)"]
#cluster0

# %%
cluster1 = cluster1.set_index(["Year","Month","Day","label"], drop=True)
cluster1 = cluster1.set_index("Station")
cluster2 = cluster2.set_index(["Year","Month","Day","label"], drop=True)
cluster2 = cluster2.set_index("Station")
cluster3 = cluster3.set_index(["Year","Month","Day","label"], drop=True)
cluster3 = cluster3.set_index("Station")
cluster4 = cluster4.set_index(["Year","Month","Day","label"], drop=True)
cluster4 = cluster4.set_index("Station")
#cluster0 = cluster0["Daily Rainfall Total (mm)"]
#cluster0

# %%
cluster0["Daily Rainfall Total (mm)"] = cluster0["Daily Rainfall Total (mm)"].astype(float)
cluster1["Daily Rainfall Total (mm)"] = cluster1["Daily Rainfall Total (mm)"].astype(float)
cluster2["Daily Rainfall Total (mm)"] = cluster2["Daily Rainfall Total (mm)"].astype(float)
cluster3["Daily Rainfall Total (mm)"] = cluster3["Daily Rainfall Total (mm)"].astype(float)
cluster4["Daily Rainfall Total (mm)"] = cluster4["Daily Rainfall Total (mm)"].astype(float)
maximize = list(cluster0["Daily Rainfall Total (mm)"].values)
maximize1 = list(cluster1["Daily Rainfall Total (mm)"].values)
maximize2 = list(cluster2["Daily Rainfall Total (mm)"].values)
maximize3 = list(cluster3["Daily Rainfall Total (mm)"].values)
maximize4 = list(cluster4["Daily Rainfall Total (mm)"].values)
#print(maximize)
print(max(maximize))
print(min(maximize))
print(max(maximize1))
print(min(maximize1))
print(max(maximize2))
print(min(maximize2))
print(max(maximize3))
print(min(maximize3))
print(max(maximize4))
print(min(maximize4))
# Out:
# 22.5
# 7.2
# 7.1
# 0.0
# 84.9
# 45.4
# 45.3
# 22.6
# 278.6
# 85.0

# %%
indices0 = cluster0.index.unique().values
idx=pd.IndexSlice
indices0
# Out:
# array(['S06', 'S07', 'S08', 'S11', 'S23', 'S24', 'S25', 'S29', 'S31',
#        'S33', 'S35', 'S36', 'S39', 'S40', 'S43', 'S44', 'S46', 'S50',
#        'S55', 'S60', 'S61', 'S63', 'S64', 'S66', 'S69', 'S71', 'S72',
#        'S77', 'S78', 'S79', 'S80', 'S81', 'S82', 'S84', 'S86', 'S88',
#        'S89', 'S90', 'S91', 'S92', 'S94', 'S101', 'S102', 'S104', 'S105',
#        'S106', 'S107', 'S108', 'S109', 'S110', 'S111', 'S112', 'S113',
#        'S114', 'S115', 'S116', 'S117', 'S118', 'S119', 'S120', 'S121',
#        'S122', 'S123'], dtype=object)

# %%
indices1 = cluster1.index.unique().values
indices2 = cluster2.index.unique().values
indices3 = cluster3.index.unique().values
indices4 = cluster4.index.unique().values
indices4
# Out:
# array(['S06', 'S07', 'S08', 'S11', 'S23', 'S24', 'S25', 'S29', 'S31',
#        'S33', 'S35', 'S36', 'S39', 'S40', 'S43', 'S44', 'S46', 'S50',
#        'S55', 'S60', 'S61', 'S63', 'S64', 'S66', 'S69', 'S71', 'S72',
#        'S77', 'S78', 'S79', 'S80', 'S81', 'S82', 'S84', 'S86', 'S88',
#        'S89', 'S90', 'S91', 'S92', 'S94', 'S101', 'S102', 'S104', 'S105',
#        'S106', 'S107', 'S108', 'S109', 'S110', 'S111', 'S112', 'S113',
#        'S114', 'S115', 'S116', 'S117', 'S118', 'S119', 'S120', 'S121',
#        'S122', 'S123'], dtype=object)

# %%
cluster0counts = pd.DataFrame()
cluster0counts["Stations"] = indices0
cluster0counts = cluster0counts.set_index("Stations")
#cluster0counts

# %%
cluster1counts = pd.DataFrame()
cluster1counts["Stations"] = indices1
cluster1counts = cluster1counts.set_index("Stations")
cluster2counts = pd.DataFrame()
cluster2counts["Stations"] = indices2
cluster2counts = cluster2counts.set_index("Stations")
cluster3counts = pd.DataFrame()
cluster3counts["Stations"] = indices3
cluster3counts = cluster3counts.set_index("Stations")
cluster4counts = pd.DataFrame()
cluster4counts["Stations"] = indices4
cluster4counts = cluster4counts.set_index("Stations")

# %%
#liist = []
print((cluster4.loc["S121","Daily Rainfall Total (mm)"]))
#print(indices4[60])
#for index in indices4:
    #try:
    #print(len(cluster4.loc[index,"Daily Rainfall Total (mm)"]))
    #liist.append(len(cluster4.loc[index,"Daily Rainfall Total (mm)"]))
    #except:
        #pass
#print(len(liist))
#print(len(indices4))
#cluster4["Daily Rainfall Total (mm)"]
# Out:
# 103.4

# %%
for index in indices0:
    length = len(cluster0.loc[index,"Daily Rainfall Total (mm)"])
    cluster0counts.loc[index,"Counts"] = length
cluster0counts
# Out:
#           Counts
# Stations
# S06       1730.0
# S07       1953.0
# S08        376.0
# S11       1938.0
# S23       1965.0
# S24       1660.0
# S25       1868.0
# S29       1689.0
# S31       1718.0
# S33       1872.0
# S35       1810.0
# S36       1733.0
# S39       1783.0
# S40       1832.0
# S43       1752.0
# S44       1871.0
# S46       1962.0
# S50       1875.0
# S55       1803.0
# S60       1668.0
# S61        341.0
# S63       1890.0
# S64       1941.0
# S66       1930.0
# S69        371.0
# S71        446.0
# S72       1554.0
# S77       1700.0
# S78       1689.0
# S79        318.0
# ...          ...
# S84        338.0
# S86        331.0
# S88        393.0
# S89        439.0
# S90        398.0
# S91        394.0
# S92        399.0
# S94        316.0
# S101       440.0
# S102       353.0
# S104       438.0
# S105       423.0
# S106       365.0
# S107       334.0
# S108       337.0
# S109       429.0
# S110       392.0
# S111       379.0
# S112       365.0
# S113       362.0
# ...

# %%
for index in indices1:
    length = len(cluster1.loc[index,"Daily Rainfall Total (mm)"])
    cluster1counts.loc[index,"Counts"] = length
#print(cluster1counts)
for index in indices2:
    length = len(cluster2.loc[index,"Daily Rainfall Total (mm)"])
    cluster2counts.loc[index,"Counts"] = length
#print(cluster2counts)
for index in indices3:
    length = len(cluster3.loc[index,"Daily Rainfall Total (mm)"])
    cluster3counts.loc[index,"Counts"] = length
#print(cluster3counts)
for index in indices4:
    try:
        length = len(cluster4.loc[index,"Daily Rainfall Total (mm)"])
        cluster4counts.loc[index,"Counts"] = length
    except:
        length = 1
        cluster4counts.loc[index,"Counts"] = length
cluster4counts
# Out:
#           Counts
# Stations
# S06         77.0
# S07         65.0
# S08         13.0
# S11         57.0
# S23         78.0
# S24         70.0
# S25         77.0
# S29         74.0
# S31         73.0
# S33         66.0
# S35         77.0
# S36         74.0
# S39         66.0
# S40         72.0
# S43         71.0
# S44         72.0
# S46         68.0
# S50         69.0
# S55         72.0
# S60         51.0
# S61          4.0
# S63         88.0
# S64         80.0
# S66         59.0
# S69         12.0
# S71         10.0
# S72         46.0
# S77         67.0
# S78         48.0
# S79          5.0
# ...          ...
# S84          9.0
# S86          8.0
# S88         11.0
# S89          6.0
# S90          7.0
# S91         10.0
# S92         12.0
# S94          9.0
# S101         9.0
# S102         5.0
# S104         7.0
# S105        13.0
# S106         6.0
# S107         4.0
# S108         4.0
# S109        16.0
# S110         9.0
# S111         8.0
# S112         7.0
# S113         6.0
# ...

# %%
cluster0counts["Counts"].sum()
# Out:
# 368912.0

# %%
fig, ax = plt.subplots(figsize=(16,6))
cluster0counts.plot.bar(ax=ax, title="Up to 13.2 mm/day")
plt.ylim((0,12500))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,6))
cluster1counts.plot.bar(ax=ax, title="Between 13.3 and 46.0 mm/day")
plt.ylim((0,12500))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,6))
cluster2counts.plot.bar(ax=ax, title="Between 46.1 and 278.6 mm/day")
plt.ylim((0,12500))
plt.show()

# %%
new_df = df.set_index("Station")

# %%
unclusteredcounts = pd.DataFrame()
unclusteredcounts["Stations"] = indices1
unclusteredcounts = unclusteredcounts.set_index("Stations")

# %%
for index in indices1:
    length = len(new_df.loc[index,"Daily Rainfall Total (mm)"])
    unclusteredcounts.loc[index,"Total Counts"] = length
unclusteredcounts
# Out:
#           Total Counts
# Stations
# S06            13655.0
# S07            13605.0
# S08             2570.0
# S11            13505.0
# S23            13665.0
# S24            13666.0
# S25            13665.0
# S29            13361.0
# S31            13436.0
# S33            13461.0
# S35            13395.0
# S36            13534.0
# S39            12668.0
# S40            12870.0
# S43            13665.0
# S44            13268.0
# S46            13465.0
# S50            13497.0
# S55            13438.0
# S60            13395.0
# S61             2694.0
# S63            13530.0
# S64            13580.0
# S66            13484.0
# S69             2653.0
# S71             2993.0
# S72            11867.0
# S77            12894.0
# S78            13278.0
# S79             2250.0
# ...                ...
# S84             2792.0
# S86             2237.0
# S88             2631.0
# S89             2979.0
# S90             2851.0
# S91             2797.0
# S92             2973.0
# ...

# %%
merger0 = pd.merge(cluster0counts,unclusteredcounts, how="inner",left_index=True, right_index=True)
#merger0

# %%
merger0["Percents"] = merger0["Counts"]/merger0["Total Counts"]*100
#merger0

# %%
merger0.loc["S80"]
# Out:
# Counts          7946.000000
# Total Counts    9617.000000
# Percents          82.624519
# Name: S80, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(16,6))
cluster0counts.plot.bar(ax=ax, title="Between 7.2 and 22.5 mm/day")
percents = list(merger0['Percents'])
x_axis = []
for p in ax.patches:
    x_axis.append(p.get_x())
#print(x_axis)
for p in ax.patches:
    #for i,label in enumerate(list(merger0.index)):
    
    num = x_axis.index(p.get_x())
    ax.annotate(("%.2f" % percents[num]+"%"), (p.get_x() * 1.005, p.get_height() +1500),size=12,rotation = "vertical")
plt.ylim((0,13500))
plt.show()

# %%
merger1 = pd.merge(cluster1counts,unclusteredcounts, how="inner",left_index=True, right_index=True)
merger2 = pd.merge(cluster2counts,unclusteredcounts, how="inner",left_index=True, right_index=True)
merger3 = pd.merge(cluster3counts,unclusteredcounts, how="inner",left_index=True, right_index=True)
merger4 = pd.merge(cluster4counts,unclusteredcounts, how="inner",left_index=True, right_index=True)
merger1["Percents"] = merger1["Counts"]/merger1["Total Counts"]*100
merger2["Percents"] = merger2["Counts"]/merger2["Total Counts"]*100
merger3["Percents"] = merger3["Counts"]/merger3["Total Counts"]*100
merger4["Percents"] = merger4["Counts"]/merger4["Total Counts"]*100

# %%
fig, ax = plt.subplots(figsize=(16,6))
cluster1counts.plot.bar(ax=ax, title="Up to 7.1 mm/day")
percents = list(merger1['Percents'])
x_axis = []
for p in ax.patches:
    x_axis.append(p.get_x())
#print(x_axis)
for p in ax.patches:
    #for i,label in enumerate(list(merger0.index)):
    
    num = x_axis.index(p.get_x())
    ax.annotate(("%.2f" % percents[num]+"%"), (p.get_x() * 1.005, p.get_height() +1500),size=12, rotation = "vertical")
plt.ylim((0,13500))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,6))
cluster2counts.plot.bar(ax=ax, title="Between 45.4 and 84.9 mm/day")
percents = list(merger2['Percents'])
x_axis = []
for p in ax.patches:
    x_axis.append(p.get_x())
#print(x_axis)
for p in ax.patches:
    #for i,label in enumerate(list(merger0.index)):
    
    num = x_axis.index(p.get_x())
    ax.annotate(("%.2f" % percents[num]+"%"), (p.get_x() * 1.005, p.get_height() +1300),size=12,rotation = "vertical")
plt.ylim((0,13500))
axes = plt.gca()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,6))
cluster3counts.plot.bar(ax=ax, title="Between 22.6 and 45.3 mm/day")
percents = list(merger3['Percents'])
x_axis = []
for p in ax.patches:
    x_axis.append(p.get_x())
#print(x_axis)
for p in ax.patches:
    #for i,label in enumerate(list(merger0.index)):
    
    num = x_axis.index(p.get_x())
    ax.annotate(("%.2f" % percents[num]+"%"), (p.get_x() * 1.005, p.get_height() +1300),size=12,rotation = "vertical")
plt.ylim((0,13500))
axes = plt.gca()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,6))
cluster4counts.plot.bar(ax=ax, title="Between 85.0 and 278.6 mm/day")
percents = list(merger4['Percents'])
x_axis = []
for p in ax.patches:
    x_axis.append(p.get_x())
#print(x_axis)
for p in ax.patches:
    #for i,label in enumerate(list(merger0.index)):
    
    num = x_axis.index(p.get_x())
    ax.annotate(("%.2f" % percents[num]+"%"), (p.get_x() * 1.005, p.get_height() +1300),size=12,rotation = "vertical")
plt.ylim((0,13500))
axes = plt.gca()
plt.show()

# %%
clusters = pd.DataFrame()
clusters["Year"] = df["Year"]
clusters["Month"] = df["Month"]
clusters["Day"] = df["Day"]
clusters = clusters.set_index(["Year","Month","Day"])
clusters
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
clusters[0] = None
clusters[1] = None
clusters[2] = None
clusters
# Out:
#                    0     1     2
# Year Month Day
# 1980 1     1    None  None  None
#            2    None  None  None
#            3    None  None  None
#            4    None  None  None
#            5    None  None  None
#            6    None  None  None
#            7    None  None  None
#            8    None  None  None
#            9    None  None  None
#            10   None  None  None
#            11   None  None  None
#            12   None  None  None
#            13   None  None  None
#            14   None  None  None
#            15   None  None  None
#            16   None  None  None
#            17   None  None  None
#            18   None  None  None
#            19   None  None  None
#            20   None  None  None
#            21   None  None  None
#            22   None  None  None
#            23   None  None  None
#            24   None  None  None
#            25   None  None  None
#            26   None  None  None
#            27   None  None  None
# ...

# %%
n = 0
for item in label:
    clusters.iloc[n][item] = df.iloc[n]["Daily Rainfall Total (mm)"]
    n +=1
clusters
# Out:
#                    0      1     2
# Year Month Day
# 1980 1     1       0   None  None
#            2       0   None  None
#            3       0   None  None
#            4       0   None  None
#            5    12.8   None  None
#            6    None   None  25.5
#            7     9.1   None  None
#            8       0   None  None
#            9       0   None  None
#            10      0   None  None
#            11      0   None  None
#            12      0   None  None
#            13      0   None  None
#            14      0   None  None
#            15      0   None  None
#            16      0   None  None
#            17      0   None  None
#            18    2.5   None  None
#            19   None  133.5  None
#            20   None  101.3  None
#            21    4.9   None  None
#            22    0.6   None  None
#            23      0   None  None
#            24      0   None  None
#            25    1.8   None  None
#            26   None   None  34.2
# ...

# %%
#print(clusters)
new_clusterss = clusters

# %%
new_clusters = new_clusterss.reset_index(drop=False)
new_clusters['Datetime'] = new_clusters[['Year', 'Month', 'Day']].apply(lambda s : pd.datetime(*s),axis = 1)
new_clusters
# Out:
#         Year  Month  Day     0      1     2   Datetime
# 0       1980      1    1     0   None  None 1980-01-01
# 1       1980      1    2     0   None  None 1980-01-02
# 2       1980      1    3     0   None  None 1980-01-03
# 3       1980      1    4     0   None  None 1980-01-04
# 4       1980      1    5  12.8   None  None 1980-01-05
# 5       1980      1    6  None   None  25.5 1980-01-06
# 6       1980      1    7   9.1   None  None 1980-01-07
# 7       1980      1    8     0   None  None 1980-01-08
# 8       1980      1    9     0   None  None 1980-01-09
# 9       1980      1   10     0   None  None 1980-01-10
# 10      1980      1   11     0   None  None 1980-01-11
# 11      1980      1   12     0   None  None 1980-01-12
# 12      1980      1   13     0   None  None 1980-01-13
# 13      1980      1   14     0   None  None 1980-01-14
# 14      1980      1   15     0   None  None 1980-01-15
# 15      1980      1   16     0   None  None 1980-01-16
# ...

# %%
#newest_df = newest_df.reset_index(drop=False)
newest_df = newest_df.set_index(["level_0","index"],drop=True)
newest_df = newest_df.set_index(["Year","Month","Day"])
print(newest_df)
newest_df['Datetime'] = pd.to_datetime(newest_df["Year"]*10000 + newest_df["Month"]*100 + newest_df["Day"], format="%Y%M%d")
newest_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/abby/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: 'Year'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
newest_df=pd.DataFrame()
for item in clusters:
    data = pd.DataFrame({item:clusters[item]})
    newest_df = newest_df.append(data).set_index(clusters[item])
newest_df
# Out:
#                                                        0  \
# 0      Year                         1980
# Month       ...
# 1      Year                         1980
# Month       ...
# 2      Year                         1980
# Month       ...
# 3      Year                         1980
# Month       ...
# 4      Year                         1980
# Month       ...
# 5      Year                         1980
# Month       ...
# 6      Year                         1980
# Month       ...
# 7      Year                         1980
# Month       ...
# 8      Year                         1980
# Month       ...
# 9      Year                         1980
# Month       ...
# 10     Year                         1980
# Month       ...
# 11     Year                         1980
# Month       ...
# 12     Year                         1980
# Month       ...
# 13     Year                         1980
# Month       ...
# 14     Year                         1980
# Month       ...
# ...

# %%
x1 = newest_df[0]
x2 = newest_df[1]
x3 = newest_df[2]
val=0.
plt.plot(x1, np.zeros_like(x1)+val,"X")
plt.plot(x2, np.zeros_like(x2)+val,"o")
plt.plot(x3, np.zeros_like(x3)+val,"s")
plt.show()

# %%
x1 = new_clusters[0]
x2 = new_clusters[1]
x3 = new_clusters[2]
y=new_clusters["Datetime"]
#val=0.
plt.plot(y, x1,"X")
plt.plot(y, x2,"o")
plt.plot(y, x3,"s")
plt.show()

# %%
newest_df = newest_df.set_index("Year","Month","Day")
newest_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item (pandas/_libs/hashtable.c:13892)()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /Users/abby/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# ...

# %%
clusters[0]"Daily Rainfall Total (mm)"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-c6280dba5a81> in <module>()
# ----> 1 clusters[0,"Daily Rainfall Total (mm)"]
#
# KeyError: (0, 'Daily Rainfall Total (mm)')
