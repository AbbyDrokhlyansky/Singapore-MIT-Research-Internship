# %%
import pandas as pd
from glob import glob
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
stations = locations["station_id"].values
stations
# Out:
# array(['S06', 'S07', 'S08', 'S11', 'S23', 'S24', 'S25', 'S29', 'S31',
#        'S33', 'S35', 'S36', 'S39', 'S40', 'S43', 'S44', 'S46', 'S50',
#        'S55', 'S60', 'S61', 'S63', 'S64', 'S66', 'S69', 'S71', 'S72',
#        'S77', 'S78', 'S79', 'S80', 'S81', 'S82', 'S84', 'S86', 'S88',
#        'S89', 'S90', 'S91', 'S92', 'S94', 'S96', 'S100', 'S101', 'S102',
#        'S104', 'S105', 'S106', 'S107', 'S108', 'S109', 'S110', 'S111',
#        'S112', 'S113', 'S114', 'S115', 'S116', 'S117', 'S118', 'S119',
#        'S120', 'S121', 'S122', 'S123', 'S241', 'S900'], dtype=object)

# %%
len(stations)
# Out:
# 67

# %%
df=pd.DataFrame()
for station in stations:
    filenames = glob("csv/{}/DAILYDATA_*.csv".format(station))
#tryyy = pd.read_csv("csv/S06/DAILYDATA_S06_198002.csv")
#tryyy
    for filename in filenames:
    #try:
        other_df = pd.read_csv(filename, encoding='windows-1252')
        other_df = other_df.replace({'—': np.nan})
        other_df = other_df[["Station","Year","Month","Day","Daily Rainfall Total (mm)"]]
        other_df["Station"] = station
    #print(other_df)
    #do test.py filename
    
        df = df.append(other_df,ignore_index=True)
    #except UnicodeDecodeError:
        #pass
    ##other_df["timestamp_sgt"] = other_df["timestamp_sgt"].astype("datetime64[ns]")
    #other_df = other_df["Year","Month","Day","Daily Rainfall"]
#another_df = df.set_index("station_id").sort_index()
#filenames
df=df.dropna()
df
# Out:
#        Station  Year  Month  Day Daily Rainfall Total (mm)
# 0          S06  1980      1    1                         0
# 1          S06  1980      1    2                         0
# 2          S06  1980      1    3                         0
# 3          S06  1980      1    4                         0
# 4          S06  1980      1    5                      12.8
# 5          S06  1980      1    6                      25.5
# 6          S06  1980      1    7                       9.1
# 7          S06  1980      1    8                         0
# 8          S06  1980      1    9                         0
# 9          S06  1980      1   10                         0
# 10         S06  1980      1   11                         0
# 11         S06  1980      1   12                         0
# 12         S06  1980      1   13                         0
# 13         S06  1980      1   14                         0
# 14         S06  1980      1   15                         0
# 15         S06  1980      1   16                         0
# 16         S06  1980      1   17                         0
# 17         S06  1980      1   18                       2.5
# 18         S06  1980      1   19                     133.5
# 19         S06  1980      1   20                     101.3
# 20         S06  1980      1   21                       4.9
# 21         S06  1980      1   22                       0.6
# 22         S06  1980      1   23                         0
# 23         S06  1980      1   24                         0
# 24         S06  1980      1   25                       1.8
# 25         S06  1980      1   26                      34.2
# 26         S06  1980      1   27                         0
# 27         S06  1980      1   28                         0
# 28         S06  1980      1   29                         0
# 29         S06  1980      1   30                         0
# ...        ...   ...    ...  ...                       ...
# 446438    S123  2017      5    2                       5.2
# 446439    S123  2017      5    3                       0.8
# 446440    S123  2017      5    4                       0.4
# 446441    S123  2017      5    5                         0
# 446442    S123  2017      5    6                         2
# 446443    S123  2017      5    7                       8.8
# 446444    S123  2017      5    8                         0
# 446445    S123  2017      5    9                         0
# 446446    S123  2017      5   10                       2.2
# 446447    S123  2017      5   11                         0
# 446448    S123  2017      5   12                      25.2
# 446449    S123  2017      5   13                       0.4
# 446450    S123  2017      5   14                         0
# 446451    S123  2017      5   15                        15
# 446452    S123  2017      5   16                       5.2
# 446453    S123  2017      5   17                         0
# 446454    S123  2017      5   18                         2
# 446455    S123  2017      5   19                         0
# 446456    S123  2017      5   20                         0
# 446457    S123  2017      5   21                       6.2
# 446458    S123  2017      5   22                      20.6
# 446459    S123  2017      5   23                         0
# 446460    S123  2017      5   24                      30.2
# 446461    S123  2017      5   25                         0
# 446462    S123  2017      5   26                      24.4
# 446463    S123  2017      5   27                         1
# 446464    S123  2017      5   28                         0
# 446465    S123  2017      5   29                       0.2
# 446466    S123  2017      5   30                      27.4
# 446467    S123  2017      5   31                      15.4
#
# [440988 rows x 5 columns]

# %%
locations = pd.read_csv("StationLocations.csv")
locations=locations.rename(columns={"Lon (d)":"longitude","Lat (d)":"latitude"})
locations
# Out:
#    station_id  longitude  latitude
# 0         S06  103.90070   1.35240
# 1         S07  103.83340   1.34150
# 2         S08  103.82710   1.37010
# 3         S11  103.69380   1.37460
# 4         S23  103.71140   1.38580
# 5         S24  103.98260   1.36780
# 6         S25  103.86540   1.41660
# 7         S29  103.93500   1.38700
# 8         S31  103.82800   1.27450
# 9         S33  103.71000   1.30810
# 10        S35  103.75560   1.33290
# 11        S36  103.86570   1.33820
# 12        S39  103.73540   1.32620
# 13        S40  103.78962   1.40440
# 14        S43  103.88780   1.33990
# 15        S44  103.68166   1.34583
# 16        S46  103.81060   1.34160
# 17        S50  103.77680   1.33370
# 18        S55  103.88600   1.38370
# 19        S60  103.82790   1.25000
# 20        S61  103.92170   1.32300
# 21        S63  103.70420   1.32750
# 22        S64  103.76030   1.38240
# 23        S66  103.73630   1.43870
# 24        S69  103.80500   1.37000
# 25        S71  103.78150   1.29230
# 26        S72  103.84820   1.27400
# 27        S77  103.81250   1.29370
# 28        S78  103.89067   1.30703
# 29        S79  103.83720   1.30040
# ..        ...        ...       ...
# 37        S90  103.81910   1.31910
# 38        S91  103.83080   1.43010
# 39        S92  103.78860   1.28410
# 40        S94  103.95280   1.36620
# 41        S96  104.03070   1.31750
# 42       S100  103.74855   1.41720
# 43       S101  103.71340   1.35053
# 44       S102  103.76800   1.18900
# 45       S104  103.78538   1.44387
# 46       S105  103.79530   1.45820
# 47       S106  103.96730   1.41680
# 48       S107  103.96250   1.31350
# 49       S108  103.87030   1.27990
# 50       S109  103.84920   1.37640
# 51       S110  103.86970   1.36061
# 52       S111  103.83650   1.31060
# 53       S112  103.70131   1.43854
# 54       S113  103.91074   1.30655
# 55       S114  103.73000   1.38000
# 56       S115  103.61843   1.29377
# 57       S116  103.75400   1.28100
# 58       S117  103.67900   1.25600
# 59       S118  103.84610   1.29940
# 60       S119  103.86660   1.30105
# 61       S120  103.81800   1.30874
# 62       S121  103.72244   1.37288
# 63       S122  103.82490   1.41731
# 64       S123  103.85770   1.32140
# 65       S241  103.99800   1.36780
# 66       S900  103.86922   1.41284
#
# [67 rows x 3 columns]

# %%
from sklearn.cluster import KMeans
#import plot_labelled_scatter

X = df["Daily Rainfall Total (mm)"]
X=X.values.reshape(-1,1)
X
kmeans = KMeans(n_clusters = 3)
kmeans.fit(X)
label = kmeans.predict(X)

#plot_labelled_scatter(X, kmeans.labels_, ['Cluster 1', 'Cluster 2', 'Cluster 3'])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters = 3)
attempt = df["Daily Rainfall Total (mm)"].values.reshape(-1,1)
kmeans.fit(attempt)
label = kmeans.predict(attempt)
label
# Out:
# array([2, 2, 2, ..., 2, 0, 0], dtype=int32)

# %%
df["label"] = label
df
# Out:
#        Station  Year  Month  Day Daily Rainfall Total (mm)  label
# 0          S06  1980      1    1                         0      2
# 1          S06  1980      1    2                         0      2
# 2          S06  1980      1    3                         0      2
# 3          S06  1980      1    4                         0      2
# 4          S06  1980      1    5                      12.8      2
# 5          S06  1980      1    6                      25.5      0
# 6          S06  1980      1    7                       9.1      2
# 7          S06  1980      1    8                         0      2
# 8          S06  1980      1    9                         0      2
# 9          S06  1980      1   10                         0      2
# 10         S06  1980      1   11                         0      2
# 11         S06  1980      1   12                         0      2
# 12         S06  1980      1   13                         0      2
# 13         S06  1980      1   14                         0      2
# 14         S06  1980      1   15                         0      2
# 15         S06  1980      1   16                         0      2
# 16         S06  1980      1   17                         0      2
# 17         S06  1980      1   18                       2.5      2
# 18         S06  1980      1   19                     133.5      1
# 19         S06  1980      1   20                     101.3      1
# 20         S06  1980      1   21                       4.9      2
# 21         S06  1980      1   22                       0.6      2
# 22         S06  1980      1   23                         0      2
# 23         S06  1980      1   24                         0      2
# 24         S06  1980      1   25                       1.8      2
# 25         S06  1980      1   26                      34.2      0
# 26         S06  1980      1   27                         0      2
# 27         S06  1980      1   28                         0      2
# 28         S06  1980      1   29                         0      2
# 29         S06  1980      1   30                         0      2
# ...        ...   ...    ...  ...                       ...    ...
# 446438    S123  2017      5    2                       5.2      2
# 446439    S123  2017      5    3                       0.8      2
# 446440    S123  2017      5    4                       0.4      2
# 446441    S123  2017      5    5                         0      2
# 446442    S123  2017      5    6                         2      2
# 446443    S123  2017      5    7                       8.8      2
# 446444    S123  2017      5    8                         0      2
# 446445    S123  2017      5    9                         0      2
# 446446    S123  2017      5   10                       2.2      2
# 446447    S123  2017      5   11                         0      2
# 446448    S123  2017      5   12                      25.2      0
# 446449    S123  2017      5   13                       0.4      2
# 446450    S123  2017      5   14                         0      2
# 446451    S123  2017      5   15                        15      0
# 446452    S123  2017      5   16                       5.2      2
# 446453    S123  2017      5   17                         0      2
# 446454    S123  2017      5   18                         2      2
# 446455    S123  2017      5   19                         0      2
# 446456    S123  2017      5   20                         0      2
# 446457    S123  2017      5   21                       6.2      2
# 446458    S123  2017      5   22                      20.6      0
# 446459    S123  2017      5   23                         0      2
# 446460    S123  2017      5   24                      30.2      0
# 446461    S123  2017      5   25                         0      2
# 446462    S123  2017      5   26                      24.4      0
# S06                             0
# S06                             0
# S06                             0
# S06                             0
# S06                             0
# S06                             0
# S06                             0
# S06                           1.1
# ...                           ...
# S123                            0
# S123                          2.6
# S123                          8.8
# S123                          0.6
# S123                          0.2
# S123                            0
# S123                            0
# S123                          5.2
# S123                          0.8
# S123                          0.4
# S123                            0
# S123                            2
# S123                          8.8
# S123                            0
# S123                            0
# S123                          2.2
# S123                            0
# S123                          0.4
# S123                            0
# S123                          5.2
# S123                            0
# S123                            2
# S123                            0
# S123                            0
# S123                          6.2
# S123                            0
# S123                            0
# S123                            1
# S123                            0
# S123                          0.2
#
# [368912 rows x 1 columns]

# %%
cluster1 = cluster1.set_index(["Year","Month","Day","label"], drop=True)
cluster1 = cluster1.set_index("Station")
cluster2 = cluster2.set_index(["Year","Month","Day","label"], drop=True)
cluster2 = cluster2.set_index("Station")
#cluster0 = cluster0["Daily Rainfall Total (mm)"]
#cluster0

# %%
#cluster0["Daily Rainfall Total (mm)"] = cluster0["Daily Rainfall Total (mm)"].astype(float)
#cluster1["Daily Rainfall Total (mm)"] = cluster1["Daily Rainfall Total (mm)"].astype(float)
#cluster2["Daily Rainfall Total (mm)"] = cluster2["Daily Rainfall Total (mm)"].astype(float)
maximize = list(cluster0["Daily Rainfall Total (mm)"].values)
maximize1 = list(cluster1["Daily Rainfall Total (mm)"].values)
maximize2 = list(cluster2["Daily Rainfall Total (mm)"].values)
#print(maximize)
print(max(maximize1))
print(min(maximize1))
print(max(maximize2))
print(min(maximize2))
# Out:
# 46.0
# 13.3
# 278.6
# 46.1

# %%
indices0 = cluster0.index.unique().values
idx=pd.IndexSlice
indices0
# Out:
# array(['S06', 'S07', 'S08', 'S11', 'S23', 'S24', 'S25', 'S29', 'S31',
#        'S33', 'S35', 'S36', 'S39', 'S40', 'S43', 'S44', 'S46', 'S50',
#        'S55', 'S60', 'S61', 'S63', 'S64', 'S66', 'S69', 'S71', 'S72',
#        'S77', 'S78', 'S79', 'S80', 'S81', 'S82', 'S84', 'S86', 'S88',
#        'S89', 'S90', 'S91', 'S92', 'S94', 'S101', 'S102', 'S104', 'S105',
#        'S106', 'S107', 'S108', 'S109', 'S110', 'S111', 'S112', 'S113',
#        'S114', 'S115', 'S116', 'S117', 'S118', 'S119', 'S120', 'S121',
#        'S122', 'S123'], dtype=object)

# %%
indices1 = cluster1.index.unique().values
indices2 = cluster2.index.unique().values

# %%
cluster0counts = pd.DataFrame()
cluster0counts["Stations"] = indices0
cluster0counts = cluster0counts.set_index("Stations")
cluster0counts
# Out:
# Empty DataFrame
# Columns: []
# Index: [S06, S07, S08, S11, S23, S24, S25, S29, S31, S33, S35, S36, S39, S40, S43, S44, S46, S50, S55, S60, S61, S63, S64, S66, S69, S71, S72, S77, S78, S79, S80, S81, S82, S84, S86, S88, S89, S90, S91, S92, S94, S101, S102, S104, S105, S106, S107, S108, S109, S110, S111, S112, S113, S114, S115, S116, S117, S118, S119, S120, S121, S122, S123]
#
# [63 rows x 0 columns]

# %%
cluster1counts = pd.DataFrame()
cluster1counts["Stations"] = indices1
cluster1counts = cluster1counts.set_index("Stations")
cluster2counts = pd.DataFrame()
cluster2counts["Stations"] = indices2
cluster2counts = cluster2counts.set_index("Stations")

# %%
for index in indices0:
    length = len(cluster0.loc[index,"Daily Rainfall Total (mm)"])
    cluster0counts.loc[index,"Counts"] = length
cluster0counts
# Out:
#            Counts
# Stations
# S06       11503.0
# S07       11227.0
# S08        2105.0
# S11       11212.0
# S23       11274.0
# S24       11793.0
# S25       11393.0
# S29       11377.0
# S31       11317.0
# S33       11220.0
# S35       11128.0
# S36       11315.0
# S39       10472.0
# S40       10663.0
# S43       11465.0
# S44       11031.0
# S46       11174.0
# S50       11157.0
# S55       11324.0
# S60       11423.0
# S61        2302.0
# S63       11225.0
# S64       11239.0
# S66       11175.0
# S69        2182.0
# S71        2471.0
# S72       10036.0
# S77       10821.0
# S78       11318.0
# S79        1892.0
# ...           ...
# S84        2406.0
# S86        1817.0
# S88        2156.0
# S89        2475.0
# S90        2369.0
# S91        2318.0
# S92        2467.0
# S94        2219.0
# S101       2418.0
# S102       2554.0
# S104       2475.0
# S105       2311.0
# S106       2467.0
# S107       2552.0
# S108       2105.0
# S109       2328.0
# S110       2328.0
# S111       2202.0
# S112       2133.0
# S113       2364.0
# S114       2218.0
# S115       1892.0
# S116       2224.0
# S117       1778.0
# S118       1984.0
# S119       2042.0
# S120       2023.0
# S121       1787.0
# S122       1980.0
# S123       1727.0
#
# [63 rows x 1 columns]

# %%
for index in indices1:
    length = len(cluster1.loc[index,"Daily Rainfall Total (mm)"])
    cluster1counts.loc[index,"Counts"] = length
for index in indices2:
    length = len(cluster2.loc[index,"Daily Rainfall Total (mm)"])
    cluster2counts.loc[index,"Counts"] = length

# %%
cluster0counts["Counts"].sum()
# Out:
# 368912.0

# %%
fig, ax = plt.subplots(figsize=(16,6))
cluster0counts.plot.bar(ax=ax, title="Up to 13.2 mm/day")
plt.ylim((0,12500))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,6))
cluster1counts.plot.bar(ax=ax, title="Between 13.3 and 46.0 mm/day")
plt.ylim((0,12500))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,6))
cluster2counts.plot.bar(ax=ax, title="Between 46.1 and 278.6 mm/day")
plt.ylim((0,12500))
plt.show()

# %%
new_df = df.set_index("Station")

# %%
unclusteredcounts = pd.DataFrame()
unclusteredcounts["Stations"] = indices1
unclusteredcounts = unclusteredcounts.set_index("Stations")

# %%
for index in indices1:
    length = len(new_df.loc[index,"Daily Rainfall Total (mm)"])
    unclusteredcounts.loc[index,"Total Counts"] = length
unclusteredcounts
# Out:
#           Total Counts
# Stations
# S06            13655.0
# S07            13605.0
# S08             2570.0
# S11            13505.0
# S23            13665.0
# S24            13666.0
# S25            13665.0
# S29            13361.0
# S31            13436.0
# S33            13461.0
# S35            13395.0
# S36            13534.0
# S39            12668.0
# S40            12870.0
# S43            13665.0
# S44            13268.0
# S46            13465.0
# S50            13497.0
# S55            13438.0
# S60            13395.0
# S61             2694.0
# S63            13530.0
# S64            13580.0
# S66            13484.0
# S69             2653.0
# S71             2993.0
# S72            11867.0
# S77            12894.0
# S78            13278.0
# S79             2250.0
# ...                ...
# S84             2792.0
# S86             2237.0
# S88             2631.0
# S89             2979.0
# S90             2851.0
# S91             2797.0
# S92             2973.0
# S94             2609.0
# S101            2966.0
# S102            2900.0
# S104            2974.0
# S105            2792.0
# S106            2881.0
# S107            2892.0
# S108            2470.0
# S109            2820.0
# S110            2784.0
# S111            2625.0
# S112            2538.0
# S113            2748.0
# S114            2709.0
# S63       11225.0       13530.0  82.963784
# S64       11239.0       13580.0  82.761414
# S66       11175.0       13484.0  82.876001
# S69        2182.0        2653.0  82.246513
# S71        2471.0        2993.0  82.559305
# S72       10036.0       11867.0  84.570658
# S77       10821.0       12894.0  83.922755
# S78       11318.0       13278.0  85.238741
# S79        1892.0        2250.0  84.088889
# ...           ...           ...        ...
# S84        2406.0        2792.0  86.174785
# S86        1817.0        2237.0  81.224855
# S88        2156.0        2631.0  81.946028
# S89        2475.0        2979.0  83.081571
# S90        2369.0        2851.0  83.093651
# S91        2318.0        2797.0  82.874508
# S92        2467.0        2973.0  82.980155
# S94        2219.0        2609.0  85.051744
# S101       2418.0        2966.0  81.523938
# S102       2554.0        2900.0  88.068966
# S104       2475.0        2974.0  83.221251
# S105       2311.0        2792.0  82.772206
# S106       2467.0        2881.0  85.629990
# S107       2552.0        2892.0  88.243430
# S108       2105.0        2470.0  85.222672
# S109       2328.0        2820.0  82.553191
# S110       2328.0        2784.0  83.620690
# S111       2202.0        2625.0  83.885714
# S112       2133.0        2538.0  84.042553
# S113       2364.0        2748.0  86.026201
# S114       2218.0        2709.0  81.875231
# S115       1892.0        2249.0  84.126278
# S116       2224.0        2641.0  84.210526
# S117       1778.0        2106.0  84.425451
# S118       1984.0        2376.0  83.501684
# S119       2042.0        2435.0  83.860370
# S120       2023.0        2441.0  82.875871
# S121       1787.0        2183.0  81.859826
# S122       1980.0        2405.0  82.328482
# S123       1727.0        2069.0  83.470275
#
# [63 rows x 3 columns]

# %%
merger0.loc["S80"]
# Out:
# Counts          7946.000000
# Total Counts    9617.000000
# Percents          82.624519
# Name: S80, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(16,6))
cluster0counts.plot.bar(ax=ax, title="Up to 13.2 mm/day")
percents = list(merger0['Percents'])
x_axis = []
for p in ax.patches:
    x_axis.append(p.get_x())
#print(x_axis)
for p in ax.patches:
    #for i,label in enumerate(list(merger0.index)):
    
    num = x_axis.index(p.get_x())
    ax.annotate(("%.2f" % percents[num]+"%"), (p.get_x() * 1.005, p.get_height() +1500),size=12,rotation = "vertical")
plt.ylim((0,13500))
plt.show()

# %%
merger1 = pd.merge(cluster1counts,unclusteredcounts, how="inner",left_index=True, right_index=True)
merger2 = pd.merge(cluster2counts,unclusteredcounts, how="inner",left_index=True, right_index=True)
merger1["Percents"] = merger1["Counts"]/merger1["Total Counts"]*100
merger2["Percents"] = merger2["Counts"]/merger2["Total Counts"]*100

# %%
fig, ax = plt.subplots(figsize=(16,6))
cluster1counts.plot.bar(ax=ax, title="Between 13.3 and 46.0 mm/day")
percents = list(merger1['Percents'])
x_axis = []
for p in ax.patches:
    x_axis.append(p.get_x())
#print(x_axis)
for p in ax.patches:
    #for i,label in enumerate(list(merger0.index)):
    
    num = x_axis.index(p.get_x())
    ax.annotate(("%.2f" % percents[num]+"%"), (p.get_x() * 1.005, p.get_height() +1500),size=12, rotation = "vertical")
plt.ylim((0,13500))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,6))
cluster2counts.plot.bar(ax=ax, title="Between 46.1 and 278.6 mm/day")
percents = list(merger2['Percents'])
x_axis = []
for p in ax.patches:
    x_axis.append(p.get_x())
#print(x_axis)
for p in ax.patches:
    #for i,label in enumerate(list(merger0.index)):
    
    num = x_axis.index(p.get_x())
    ax.annotate(("%.2f" % percents[num]+"%"), (p.get_x() * 1.005, p.get_height() +1300),size=12,rotation = "vertical")
plt.ylim((0,13500))
axes = plt.gca()
plt.show()

# %%
clusters = pd.DataFrame()
clusters["Year"] = df["Year"]
clusters["Month"] = df["Month"]
clusters["Day"] = df["Day"]
clusters = clusters.set_index(["Year","Month","Day"])
clusters
# Out:
# Empty DataFrame
# Columns: []
# Index: [(1980, 1, 1), (1980, 1, 2), (1980, 1, 3), (1980, 1, 4), (1980, 1, 5), (1980, 1, 6), (1980, 1, 7), (1980, 1, 8), (1980, 1, 9), (1980, 1, 10), (1980, 1, 11), (1980, 1, 12), (1980, 1, 13), (1980, 1, 14), (1980, 1, 15), (1980, 1, 16), (1980, 1, 17), (1980, 1, 18), (1980, 1, 19), (1980, 1, 20), (1980, 1, 21), (1980, 1, 22), (1980, 1, 23), (1980, 1, 24), (1980, 1, 25), (1980, 1, 26), (1980, 1, 27), (1980, 1, 28), (1980, 1, 29), (1980, 1, 30), (1980, 1, 31), (1980, 2, 1), (1980, 2, 2), (1980, 2, 3), (1980, 2, 4), (1980, 2, 5), (1980, 2, 6), (1980, 2, 7), (1980, 2, 8), (1980, 2, 9), (1980, 2, 10), (1980, 2, 11), (1980, 2, 12), (1980, 2, 13), (1980, 2, 14), (1980, 2, 15), (1980, 2, 16), (1980, 2, 17), (1980, 2, 18), (1980, 2, 19), (1980, 2, 20), (1980, 2, 21), (1980, 2, 22), (1980, 2, 23), (1980, 2, 24), (1980, 2, 25), (1980, 2, 26), (1980, 2, 27), (1980, 2, 28), (1980, 2, 29), (1980, 3, 1), (1980, 3, 2), (1980, 3, 3), (1980, 3, 4), (1980, 3, 5), (1980, 3, 6), (1980, 3, 7), (1980, 3, 8), (1980, 3, 9), (1980, 3, 10), (1980, 3, 11), (1980, 3, 12), (1980, 3, 13), (1980, 3, 14), (1980, 3, 15), (1980, 3, 16), (1980, 3, 17), (1980, 3, 18), (1980, 3, 19), (1980, 3, 20), (1980, 3, 21), (1980, 3, 22), (1980, 3, 23), (1980, 3, 24), (1980, 3, 25), (1980, 3, 26), (1980, 3, 27), (1980, 3, 28), (1980, 3, 29), (1980, 3, 30), (1980, 3, 31), (1980, 4, 1), (1980, 4, 2), (1980, 4, 3), (1980, 4, 4), (1980, 4, 5), (1980, 4, 6), (1980, 4, 7), (1980, 4, 8), (1980, 4, 9), ...]
#
# [440988 rows x 0 columns]

# %%
clusters[0] = None
clusters[1] = None
clusters[2] = None
clusters
# Out:
#                    0     1     2
# Year Month Day
# 1980 1     1    None  None  None
#            2    None  None  None
#            3    None  None  None
#            4    None  None  None
#            5    None  None  None
#            6    None  None  None
#            7    None  None  None
#            8    None  None  None
#            9    None  None  None
#            10   None  None  None
#            11   None  None  None
#            12   None  None  None
#            13   None  None  None
#            14   None  None  None
#            15   None  None  None
#            16   None  None  None
# 5       1980      1    6  None   None  25.5 1980-01-06
# 6       1980      1    7   9.1   None  None 1980-01-07
# 7       1980      1    8     0   None  None 1980-01-08
# 8       1980      1    9     0   None  None 1980-01-09
# 9       1980      1   10     0   None  None 1980-01-10
# 10      1980      1   11     0   None  None 1980-01-11
# 11      1980      1   12     0   None  None 1980-01-12
# 12      1980      1   13     0   None  None 1980-01-13
# 13      1980      1   14     0   None  None 1980-01-14
# 14      1980      1   15     0   None  None 1980-01-15
# 15      1980      1   16     0   None  None 1980-01-16
# 16      1980      1   17     0   None  None 1980-01-17
# 17      1980      1   18   2.5   None  None 1980-01-18
# 18      1980      1   19  None  133.5  None 1980-01-19
# 19      1980      1   20  None  101.3  None 1980-01-20
# 20      1980      1   21   4.9   None  None 1980-01-21
# 21      1980      1   22   0.6   None  None 1980-01-22
# 22      1980      1   23     0   None  None 1980-01-23
# 23      1980      1   24     0   None  None 1980-01-24
# 24      1980      1   25   1.8   None  None 1980-01-25
# 25      1980      1   26  None   None  34.2 1980-01-26
# 26      1980      1   27     0   None  None 1980-01-27
# 27      1980      1   28     0   None  None 1980-01-28
# 28      1980      1   29     0   None  None 1980-01-29
# 29      1980      1   30     0   None  None 1980-01-30
# ...      ...    ...  ...   ...    ...   ...        ...
# 440958  2017      5    2     0   None  None 2017-05-02
# 440959  2017      5    3     0   None  None 2017-05-03
# 440960  2017      5    4     4   None  None 2017-05-04
# 440961  2017      5    5   9.8   None  None 2017-05-05
# 440962  2017      5    6     0   None  None 2017-05-06
# 440963  2017      5    7  None   None  14.4 2017-05-07
# 440964  2017      5    8     0   None  None 2017-05-08
# 440965  2017      5    9     0   None  None 2017-05-09
# 440966  2017      5   10   7.8   None  None 2017-05-10
# 440967  2017      5   11     0   None  None 2017-05-11
# 440968  2017      5   12   0.4   None  None 2017-05-12
# 440969  2017      5   13     0   None  None 2017-05-13
# 440970  2017      5   14     0   None  None 2017-05-14
# 440971  2017      5   15   7.4   None  None 2017-05-15
# 440972  2017      5   16   3.2   None  None 2017-05-16
# 440973  2017      5   17     0   None  None 2017-05-17
# 440974  2017      5   18   2.6   None  None 2017-05-18
# 440975  2017      5   19     0   None  None 2017-05-19
# 440976  2017      5   20     0   None  None 2017-05-20
# 440977  2017      5   21  None   None  40.2 2017-05-21
# 440978  2017      5   22  None   None    23 2017-05-22
# 440979  2017      5   23     0   None  None 2017-05-23
# 440980  2017      5   24  11.8   None  None 2017-05-24
# 440981  2017      5   25     0   None  None 2017-05-25
# 440982  2017      5   26  None   None    20 2017-05-26
# 440983  2017      5   27   0.2   None  None 2017-05-27
# 440984  2017      5   28     0   None  None 2017-05-28
# 440985  2017      5   29     0   None  None 2017-05-29
# 440986  2017      5   30  None   None  20.2 2017-05-30
# 440987  2017      5   31  None     61  None 2017-05-31
#
# [440988 rows x 7 columns]

# %%
#newest_df = newest_df.reset_index(drop=False)
newest_df = newest_df.set_index(["level_0","index"],drop=True)
newest_df = newest_df.set_index(["Year","Month","Day"])
print(newest_df)
newest_df['Datetime'] = pd.to_datetime(newest_df["Year"]*10000 + newest_df["Month"]*100 + newest_df["Day"], format="%Y%M%d")
newest_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/abby/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: 'Year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-9363ca2d5af0> in <module>()
#       1 #newest_df = newest_df.reset_index(drop=False)
#       2 newest_df = newest_df.set_index(["level_0","index"],drop=True)
# ----> 3 newest_df = newest_df.set_index(["Year","Month","Day"])
#       4 print(newest_df)
#       5 newest_df['Datetime'] = pd.to_datetime(newest_df["Year"]*10000 + newest_df["Month"]*100 + newest_df["Day"], format="%Y%M%d")
#
# /Users/abby/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    2926                 names.append(None)
#    2927             else:
# -> 2928                 level = frame[col]._values
#    2929                 names.append(col)
#    2930                 if drop:
#
# /Users/abby/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# /Users/abby/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# /Users/abby/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# /Users/abby/anaconda/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/abby/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: 'Year'

# %%
newest_df=pd.DataFrame()
for item in clusters:
    data = pd.DataFrame({item:clusters[item]})
    newest_df = newest_df.append(data).set_index(clusters[item])
newest_df
# Out:
#                                                        0  \
# 0      Year                         1980
# Month       ...
# 1      Year                         1980
# Month       ...
# 2      Year                         1980
# Month       ...
# 3      Year                         1980
# Month       ...
# 4      Year                         1980
# Month       ...
# 5      Year                         1980
# Month       ...
# 6      Year                         1980
# Month       ...
# 7      Year                         1980
# Month       ...
# 8      Year                         1980
# Month       ...
# 9      Year                         1980
# Month       ...
# 10     Year                         1980
# Month       ...
# 11     Year                         1980
# Month       ...
# 12     Year                         1980
# Month       ...
# 13     Year                         1980
# Month       ...
# 14     Year                         1980
# Month       ...
# 15     Year                         1980
# Month       ...
# 16     Year                         1980
# Month       ...
# 17     Year                         1980
# Month       ...
# 18     Year                         1980
# Month       ...
# 19     Year                         1980
# Month       ...
# 20     Year                         1980
# Month       ...
# 21     Year                         1980
# Month       ...
# 22     Year                         1980
# Month       ...
# 23     Year                         1980
# Month       ...
# 24     Year                         1980
# Month       ...
# 25     Year                         1980
# Month       ...
# 26     Year                         1980
# Month       ...
# 27     Year                         1980
# Month       ...
# 28     Year                         1980
# Month       ...
# 29     Year                         1980
# Month       ...
# ...                                                  ...
# 13436                                                NaN
# 13437                                                NaN
# 13438                                                NaN
# 13439                                                NaN
# 13440                                                NaN
# 13441                                                NaN
# 13442                                                NaN
# 13443                                                NaN
# 13444                                                NaN
# 13445                                                NaN
# 13446                                                NaN
# 13447                                                NaN
# 13448                                                NaN
# 13449                                                NaN
# 13450                                                NaN
# 13451                                                NaN
# 13452                                                NaN
# 13453                                                NaN
# 13454                                                NaN
# 13455                                                NaN
# 13456                                                NaN
# 13457                                                NaN
# 13458                                                NaN
# 13459                                                NaN
# 13460                                                NaN
# 13461                                                NaN
# 13462                                                NaN
# 13463                                                NaN
# 13464                                                NaN
# 13465                                                NaN
#
#                                                        1    2
# 0                                                    NaN  NaN
# 1                                                    NaN  NaN
# 2                                                    NaN  NaN
# 3                                                    NaN  NaN
# 4                                                    NaN  NaN
# 5                                                    NaN  NaN
# 6                                                    NaN  NaN
# 7                                                    NaN  NaN
# 8                                                    NaN  NaN
# 9                                                    NaN  NaN
# 10                                                   NaN  NaN
# 11                                                   NaN  NaN
# 12                                                   NaN  NaN
# 13                                                   NaN  NaN
# 14                                                   NaN  NaN
# 15                                                   NaN  NaN
# 16                                                   NaN  NaN
# 17                                                   NaN  NaN
# 18                                                   NaN  NaN
# 19                                                   NaN  NaN
# 20                                                   NaN  NaN
# 21                                                   NaN  NaN
# 22                                                   NaN  NaN
# 23                                                   NaN  NaN
# 24                                                   NaN  NaN
# 25                                                   NaN  NaN
# 26                                                   NaN  NaN
# 27                                                   NaN  NaN
# 28                                                   NaN  NaN
# 29                                                   NaN  NaN
# ...                                                  ...  ...
# 13436  Year                         2012
# Month       ...  NaN
# 13437  Year                          2012
# Month      ...  NaN
# 13438  Year                         2013
# Month       ...  NaN
# 13439  Year                         2013
# Month       ...  NaN
# 13440  Year                         2013
# Month       ...  NaN
# 13441  Year                         2013
# Month       ...  NaN
# 13442  Year                         2013
# Month       ...  NaN
# 13443  Year                         2013
# Month       ...  NaN
# 13444  Year                         2013
# Month       ...  NaN
# 13445  Year                          2013
# Month      ...  NaN
# 13446  Year                         2013
# Month       ...  NaN
# 13447  Year                         2014
# Month       ...  NaN
# 13448  Year                         2014
# Month       ...  NaN
# 13449  Year                         2014
# Month       ...  NaN
# 13450  Year                         2014
# Month       ...  NaN
# 13451  Year                         2014
# Month       ...  NaN
# 13452  Year                         2014
# Month       ...  NaN
# 13453  Year                         2014
# Month       ...  NaN
# 13454  Year                         2015
# Month       ...  NaN
# 13455  Year                         2015
# Month       ...  NaN
# 13456  Year                         2016
# Month       ...  NaN
# 13457  Year                         2016
# Month       ...  NaN
# 13458  Year                         2016
# Month       ...  NaN
# 13459  Year                         2016
# Month       ...  NaN
# 13460  Year                         2016
# Month       ...  NaN
# 13461  Year                         2017
# Month       ...  NaN
# 13462  Year                         2017
# Month       ...  NaN
# 13463  Year                         2017
# Month       ...  NaN
# 13464  Year                         2017
# Month       ...  NaN
# 13465  Year                         2017
# Month       ...  NaN
#
# [440988 rows x 3 columns]

# %%
x1 = newest_df[0]
x2 = newest_df[1]
x3 = newest_df[2]
val=0.
plt.plot(x1, np.zeros_like(x1)+val,"X")
plt.plot(x2, np.zeros_like(x2)+val,"o")
plt.plot(x3, np.zeros_like(x3)+val,"s")
plt.show()

# %%
x1 = new_clusters[0]
x2 = new_clusters[1]
x3 = new_clusters[2]
y=new_clusters["Datetime"]
#val=0.
plt.plot(y, x1,"X")
plt.plot(y, x2,"o")
plt.plot(y, x3,"s")
plt.show()

# %%
newest_df = newest_df.set_index("Year","Month","Day")
newest_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item (pandas/_libs/hashtable.c:13892)()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /Users/abby/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5169)()
#
# KeyError: 'Year'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item (pandas/_libs/hashtable.c:13892)()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-dd403848b03e> in <module>()
# ----> 1 newest_df = newest_df.set_index("Year","Month","Day")
#       2 newest_df
#
# /Users/abby/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    2926                 names.append(None)
#    2927             else:
# -> 2928                 level = frame[col]._values
#    2929                 names.append(col)
#    2930                 if drop:
#
# /Users/abby/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# /Users/abby/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# /Users/abby/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# /Users/abby/anaconda/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/abby/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5169)()
#
# KeyError: 'Year'

# %%
clusters[0]"Daily Rainfall Total (mm)"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-c6280dba5a81> in <module>()
# ----> 1 clusters[0,"Daily Rainfall Total (mm)"]
#
# KeyError: (0, 'Daily Rainfall Total (mm)')
